# %%
import sys
sys.path.append('../src')
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


from vgs.config import vgsales

# %% [markdown]
#  ***

# %%
vgsales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsales.shape
# Out:
# (16598, 11)

# %%
vgsales.isnull().values.any()
# Out:
# True

# %% [markdown]
# ## Detecting how many missing values and which

# %%
null_columns = vgsales.columns[vgsales.isnull().any()]
vgsales[null_columns].isnull().sum()
# Out:
# Year         271
# Publisher     58
# dtype: int64

# %% [markdown]
#  ## Dropping null values since it is not much and will not effect our

# %%
vgsales = vgsales.dropna()
vgsales.shape
# Out:
# (16291, 11)

# %% [markdown]
# ### There was an incomplete value of game in 2020 distracting our dataset, we removed values after year 2017.

# %%
vgsales = vgsales[vgsales["Year"]<2017.0]

# %% [markdown]
#  ***
# # Explotary Data Analysis

# %% [markdown]
# ### Correlation in Data

# %%
matrix = vgsales.corr()
plt.figure(figsize=(8,6))
g=sns.heatmap(matrix,annot=True,cmap="YlGn_r")

# %% [markdown]
# #### In correlation, positive values show positive correlation whereas negatives inverse correlation.

# %%
vgsales.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16287.000000  16287.000000  16287.000000  16287.000000  16287.000000
# mean    8288.969853   2006.402775      0.265695      0.147768      0.078849
# std     4792.138597      5.830382      0.822525      0.509360      0.311916
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4131.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8291.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12437.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2016.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16287.000000  16287.000000
# mean       0.048437      0.541022
# std        0.190105      1.567520
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# max       10.570000     82.740000

# %% [markdown]
# ### Video Game Sales by million in Years

# %%
df = vgsales.groupby(by='Year').sum()
df.plot.line(figsize=(10,10), grid="on");
plt.ylabel("Sales in million $")
# Out:
# Text(0, 0.5, 'Sales in million $')

# %%
def sales(genre):
    for i in genre:
        genre_sales = vgsales[vgsales['Genre'] == i]
        plt.figure(figsize=(10,8), dpi=80)
        genre_sales[['Year','Global_Sales']].groupby('Year')['Global_Sales'].sum().plot(label=i)
        plt.legend()
        plt.title(i)

# %%
sales(['Action'])

# %%
plt.figure(figsize=(10,10))
plt.hist(vgsales.Year.values,bins=20)
plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
val
# Out:
# <ipython-input-81-3a698c34dbb9>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   val = genres['NA_Sales','EU_Sales','JP_Sales','Other_Sales'].aggregate(np.mean)
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action        0.265160  0.158917  0.048812     0.056898
# Adventure     0.080008  0.050031  0.040808     0.013108
# Fighting      0.264043  0.119617  0.104246     0.043289
# Misc          0.235421  0.125605  0.063268     0.043843
# Platform      0.509703  0.229314  0.149314     0.058869
# Puzzle        0.214053  0.088632  0.099439     0.021877
# Racing        0.291371  0.192906  0.046212     0.062596
# Role-Playing  0.222411  0.127772  0.238590     0.040450
# Shooter       0.448643  0.242161  0.029782     0.079485
# Simulation    0.214298  0.133436  0.075018     0.037001
# Sports        0.290838  0.161172  0.058490     0.057574
# Strategy      0.101239  0.066925  0.073284     0.016761

# %%
genres = vgsales.groupby(['Genre'])
val = genres['NA_Sales','EU_Sales','JP_Sales','Other_Sales'].aggregate(np.mean)
val.plot(kind='bar',figsize=(20,12))
plt.xlabel('Genre',fontsize=20)
plt.ylabel('Sale of games by region',fontsize=20)
plt.title('Sales in regions by Genre',fontsize=20)
# Out:
# <ipython-input-89-a0b395b3bf23>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   val = genres['NA_Sales','EU_Sales','JP_Sales','Other_Sales'].aggregate(np.mean)
# Text(0.5, 1.0, 'Sales in regions by Genre')
